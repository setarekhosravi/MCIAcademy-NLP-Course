# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def read_file(path_to_file):

  with open(path_to_file, 'r') as ptr:
      for line in ptr:      
        tokens = line.split('\t')
        print(tokens)
    
  return

# %%
read_file('/content/drive/MyDrive/dataset/data.txt')
# Out:
# ['QuestionID', 'Question', 'DocumentID', 'DocumentTitle', 'SentenceID', 'Sentence', 'Label\n']
# ['Q0', 'HOW AFRICAN AMERICANS WERE IMMIGRATED TO THE US', 'D0', 'African immigration to the United States', 'D0-0', 'African immigration to the United States refers to immigrants to the United States who are or were nationals of Africa .', '0\n']
# ['Q0', 'HOW AFRICAN AMERICANS WERE IMMIGRATED TO THE US', 'D0', 'African immigration to the United States', 'D0-1', 'The term African in the scope of this article refers to geographical or national origins rather than racial affiliation.', '0\n']
# ['Q0', 'HOW AFRICAN AMERICANS WERE IMMIGRATED TO THE US', 'D0', 'African immigration to the United States', 'D0-2', 'From the Immigration and Nationality Act of 1965 to 2007, an estimated total of 0.8 to 0.9 million Africans immigrated to the United States, accounting for roughly 3.3% of total immigration to the United States during this period.', '0\n']
# ...
